# %% [markdown]
# ## 🌟 Data Processing and KNN Insights
#
# ---
#
# ### 🛠 1. Data Merging
#
# Data from `animes` and `user_scores_train` are merged to form:
#
# - **anime_fulldata_train**: This dataset combines the information of animes with user scores to create a training dataset.
# - **anime_fulldata_test**: This is the test dataset, kept aside to validate the machine learning model.
#
# ### 🔧 2. Data Cleaning & Visualization
#
# The data is cleaned and columns are renamed to form:
#
# - **anime_fulldata**: This dataset is the result of the cleaning and is used for visualization.
#
# ### 🔄 3. Data Preprocessing
#
# Data preprocessing steps include:
#
# - **Duration Conversion**: The function `convert_to_minutes` is used to standardize all durations to minutes.
# - **One-hot Encoding**: The function `process_combined_one_hot_encoding` is applied to process categorical variables into a format suitable for modeling.
# - **Feature Processing**: The function `process_combined_features` is used to process genres and features into a suitable format.
#
# ### 🌌 4. KNN: The Nearest Neighbors Algorithm
#
# For the KNN algorithm:
#
# - **Regular KNN**: This is the standard KNN algorithm that works by finding the nearest neighbors.
# - **Weighted KNN**: This variant gives more importance to nearer neighbors in the vote.
#
# Metrics like `cosine_similarity` are used to determine similarity and `mean_absolute_error` to measure the model's accuracy.
#
# ### 🧭 5. Model's Journey
#
# Steps in modeling include:
#
# - **Data Normalization**: Data is normalized using MinMaxScaler to ensure that all features are on the same scale.
# - **Cross-Validation**: A k-fold cross-validation is applied with k=5 to validate the model's performance.
# - **Model Testing & Visualization**: After determining the best 'k' through cross-validation, the model is tested and the results visualized.
#
# ---

# %% [markdown]
# # Assignment 1: Part 1
#
# ## Part I: Theory Questions

# %% [markdown]
# ---
# ## **k-Nearest Neighbor Classification**
# ---

# %% [markdown]
# ### Question 1:
#
# > **Assume that you have a large training dataset. Specify a disadvantage of the k-Nearest Neighbor method when using it during testing. State also your reason about your answer.**
#
# **Answer:**
# A notable drawback of the k-Nearest Neighbor (k-NN) method, especially during the testing phase, is its substantial computational expense and inefficiency. The reason for this lies in the core mechanics of the algorithm: for each incoming test instance, k-NN must compute the distance between this instance and every single sample within the training dataset to identify the "k" nearest neighbors.
#
# This process is inherently computation-heavy, and its intensity only escalates as the dataset expands. The algorithm doesn't just calculate distances; it also sorts them to pinpoint the nearest neighbors and then conducts a majority vote or averages the labels in regression scenarios. Consequently, in the context of a large dataset, the system might end up performing millions — or more — of distance computations, each contributing to a slower classification process. This computational demand, paired with the time it takes, marks a significant inefficiency in the k-NN method when handling large datasets during testing.

# %% [markdown]
# ### Question 2:
#
# > **Considering the image below, state an optimal k-value depending on that the algorithm you are using is k-Nearest Neighbor. State also your reason behind the optimal value you preferred.**
# >
# > ![Optimal k-value Illustration](attachment:image.png)
#
# **Answer:**
# The optimal k-value for the k-Nearest Neighbor (k-NN) algorithm in this scenario would be "k=11". This choice is based on the principle of minimizing the validation error, which is a crucial metric for assessing how well our model is likely to perform on unseen data. In the context of the provided image, it's observed that the validation error is at its lowest when "k" is set to 11. This indicates that at k=11, our model achieves the best balance between fitting the training data and generalizing to new data, thereby making it the most suitable choice for this particular scenario.

# %% [markdown]
# ### Question 3:
#
# > **Assume that you have the following training set of positive (+), negative (-) instances, and a single test instance (o) as shown in the image below (Figure 1). It's also assumed that the Euclidean metric is used for measuring the distance between instances and that every nearest neighbor instance affects the final vote equally. Based on this scenario:**
# >
# > - **For K=1:** What is the class appointed to the test instance? Please provide the reasoning behind your answer.
# > - **For K=3:** What is the class appointed to the test instance? Please provide the reasoning behind your answer.
# > - **For K=5:** What is the class appointed to the test instance? Please provide the reasoning behind your answer.
# >
# > ![Training Set Instances](attachment:image.png)
#
# **Answer:**
# - **For K=1:** The class assigned to the test instance is negative (-). This is because, with k set to 1, the k-NN algorithm classifies the test instance based on the nearest single point in the training set. Here, the closest neighbor to the test instance (o) is a negative (-) instance.
#
# - **For K=3:** The class assigned to the test instance is still negative (-). With k set to 3, the algorithm considers the three closest points to the test instance. In this case, two of the three nearest neighbors are negative (-) and one is positive (+). Since the majority (two out of three) are negative, the test instance is classified as negative (-).
#
# - **For K=5:** The class assigned to the test instance becomes positive (+). When k is 5, the algorithm takes into account the five nearest neighbors. Among these, three are positive (+) and two are negative (-). As the majority (three out of five) are positive, the test instance is classified as positive (+). This scenario highlights the k-NN algorithm's sensitivity to the choice of "k", demonstrating how a larger "k" value can alter the classification outcome by considering a broader set of neighbors.

# %% [markdown]
# ### Question 4:
#
# > **Fill in the blanks with T (True) or F (False) for the statements below:**
# > - If all instances of the data have the same scale, then k-Nearest Neighbor’s performance increases drastically. __(True)__
# > - While k-Nearest Neighbor performs well with a small number of input variables, its performance decreases when the number of inputs becomes large. __(True)__
# > - k-Nearest Neighbor makes no assumptions about the functional form of the problem it handles. __(True)__

# %% [markdown]
# ---
# ## Linear Regression
# ---

# %% [markdown]
# ### Question 1:
#
# > **Assume you have a scenario where five students have registered for a class that includes a midterm and a final exam. The students' marks from these two exams are presented in the table below:**
# >
# > ![Student Marks Table](attachment:image-2.png)
# >
# > **You aim to develop a model of the form $f_{\theta}(x) = \theta_0 + \theta_1 x_1 + \theta_2 x_2$ to fit the above data, where $x_1$ represents the midterm exam score and $x_2$ represents the square of the midterm score. Additionally, you plan to implement feature scaling (by dividing by the "max-min", or range, of a feature) and mean normalization.**
# >
# > - **What is the normalized value of the feature $x_{5}^{2}$?**
#
# **Answer:**
#
# To find the normalized value of the feature $x_{5}^{2}$, we use the formula for feature scaling:
#
# $$
# x' = \frac{x - \mu}{S}
# $$
#
# where $x'$ is the normalized value, $\mu$ is the average of the original $x_2$ values, and $S$ is the range of $x_2$ values.
#
# First, we calculate the average $\mu$ and range $S$ of the original $x_2$ values.
#
# The $x_2$ values (Midterm Score squared) are: 7569, 4900, 8464, 4489, and 2025.
#
# 1. Calculate $\mu$:
# $$
# \mu = \frac{7569 + 4900 + 8464 + 4489 + 2025}{5} = \frac{27447}{5} = 5489.4
# $$
#
# 2. Calculate $S$ (the range of $x_2$, which is max - min):
# $$
# S = \max(x_2) - \min(x_2) = 8464 - 2025 = 6439
# $$
#
# Now, we can find the normalized value for $x_{5}^{2}$:
#
# $$
# x' = \frac{x - \mu}{S} = \frac{2025 - 5489.4}{6439} = \frac{-3464.4}{6439} \approx -0.538
# $$
#
# The normalized value of the feature $x_{5}^{2}$ for the 5th student is approximately -0.538.

# %% [markdown]
# ### Question 2:
#
# > **Considering the figure below, which of the offsets is used in the least squares line fit for linear regression? Assume that the horizontal axis represents the independent variable and the vertical axis represents the dependent variable. Provide your answer along with a thorough explanation.**
# >
# > ![Linear Regression Graph](attachment:image.png)
#
# **Answer:**
# In the context of linear regression, particularly the least squares method, it's the vertical offsets that are utilized. This approach is adopted because these offsets, or residuals, are the vertical distances between the actual data points (observed values) and the fitted line (predicted values). These distances are parallel to the y-axis (dependent variable), and minimizing their sum is the core principle behind the least squares method. This minimization directly reduces the discrepancies between the actual data points and the predictions, leading to a model that best fits the observed data.

# %% [markdown]
# ### Question 3:
#
# > **Considering the table below, consisting of four training examples:**
# >
# > ![Training Data Table](attachment:image.png)
# >
# > **Assume that you are trying to fit the data above to the linear regression model $f_{\theta}(x) = \theta_0 + \theta_1 x_1$. Determine the values of $\theta_0$ and $\theta_1$ using the closed-form solution $\theta = (X^T X)^{-1} X^T y$. Also, specify the dimension values of $X$, $y$, and $\theta$ matrices. Finally, demonstrate your calculations step by step.**
#
# **Answer:**
#
# ![Calculations](attachment:image-2.png)
#
# *Please look at the attached image for detailed calculations.*

# %% [markdown]
# ### Question 4:
#
# > **State a valid reason for implementing feature scaling in data preprocessing. Elaborate on why your reason is valid, providing detailed explanations to support your reasoning.**
#
# **Answer:**
# Feature scaling is crucial in data preprocessing primarily because it standardizes the range of independent variables or features of data. This standardization is vital as it ensures that the gradient descent optimization algorithm converges more efficiently and quickly. It achieves this by reshaping the cost function into a more symmetrical shape, which in turn helps in a smoother and faster convergence.
#
# This process is essential because it equalizes the scales of the features, preventing any single feature from dominating the others due to its range. Without feature scaling, the algorithm might oscillate extensively around the minimum or take an elongated path, delaying convergence. By bringing all features to the same scale, the path towards the minimum is reduced, thereby accelerating the model's training time.

# %% [markdown]
# # Assignment 1: Part 2

# %%
#Let's import all the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import KFold
import plotly.graph_objects as go
from wordcloud import WordCloud, STOPWORDS
from collections import defaultdict
from termcolor import colored
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore")

# %%
# Style for dataframes to look better in the notebook

def style_dataframe(df):
    df_html = df.to_html(index=False)

    css = """
    <style type=\"text/css\">
    table {
        color: #333; /* Lighten up font color */
        font-family: Helvetica, Arial, sans-serif;
        width: 640px;
        border-collapse:
        collapse; 
        border-spacing: 0;
        margin: 20px auto;
    }

    td, th {
        border: 1px solid transparent; /* No more visible border */
        height: 30px;
        transition: all 0.3s;  /* Simple transition for hover effect */
    }

    th {
        background: #DFDFDF;  /* Darken header a bit */
        font-weight: bold;
    }

    td {
        background: #FAFAFA;
        text-align: center;
    }

    /* Cells in even rows (2,4,6...) are one color */
    tr:nth-child(even) td { background: #F1F1F1; }

    /* Cells in odd rows (1,3,5...) are another (excludes header cells)  */
    tr:nth-child(odd) td { background: #FEFEFE; }

    tr td:hover { background: #666; color: #FFF; } /* Hover cell effect! */
    </style>
    """

    # Return the styled HTML
    return HTML(css + df_html)

# %%
# Load datasets
animes = pd.read_csv('animes.csv')
user_scores_train = pd.read_csv('user_rates_train.csv')
user_scores_test = pd.read_csv('user_rates_test.csv')

# %%
# Merging data
anime_fulldata_train = pd.merge(animes, user_scores_train, on='anime_id', suffixes= ['', '_user'])
anime_fulldata_test = pd.merge(animes, user_scores_test, on='anime_id', suffixes= ['', '_user'])

# Renaming columns
anime_fulldata_train = anime_fulldata_train.rename(columns={'Name': 'anime_title', 'rating': 'user_rating'})
anime_fulldata_test = anime_fulldata_test.rename(columns={'Name': 'anime_title', 'rating': 'user_rating'})

# Drop unnecessary columns
anime_fulldata_train = anime_fulldata_train.drop(['Anime Title'], axis=1)
anime_fulldata_test = anime_fulldata_test.drop(['Anime Title'], axis=1)

# Combine train and test data for visualization
anime_fulldata = pd.concat([anime_fulldata_train, anime_fulldata_test], axis=0, ignore_index=True)

# %%
for i in anime_fulldata_train.isnull().sum() + anime_fulldata_test.isnull().sum():
    if(i>0):
        print(colored("There are null values in the dataset","red"))
        break
    else:
        print(colored("There are no null values in the dataset","green"))
        break
# Out:
# There are no null values in the dataset

# %%
#Preprocessing the data

def convert_to_minutes(duration_str):
    minutes = -1  # Default value for unparseable strings or unknowns
    # Check if duration is in hours and minutes
    if 'hr' in duration_str and 'min' in duration_str:
        time = re.findall(r'(\d+)\s*hr\s*(\d+)\s*min', duration_str)
        minutes = int(time[0][0]) * 60 + int(time[0][1])
    # Check if duration is in hours
    elif 'hr' in duration_str:
        time = re.findall(r'(\d+)\s*hr', duration_str)
        minutes = int(time[0]) * 60
    # Check if duration is in minutes
    elif 'min' in duration_str:
        time = re.findall(r'(\d+)\s*min', duration_str)
        minutes = int(time[0])
    # Check if duration is in seconds
    elif 'sec' in duration_str:
        time = re.findall(r'(\d+)\s*sec', duration_str)
        # Convert seconds to minutes;
        minutes = int(time[0]) / 60.0  
    # For 'Unknown' or other unhandled cases, we keep the default value of -1

    return minutes

def process_combined_one_hot_encoding(train_df, test_df, columns):
    combined_df = pd.concat([train_df, test_df], axis=0)
    
    for column in columns:
        dummies = pd.get_dummies(combined_df[column], prefix=column)
        combined_df = pd.concat([combined_df, dummies], axis=1)
        combined_df = combined_df.drop(column, axis=1)
        combined_df[dummies.columns] = combined_df[dummies.columns].astype(int)

    # Splitting the datasets back to train and test
    train_df = combined_df.iloc[:len(train_df)]
    test_df = combined_df.iloc[len(train_df):]
    
    return train_df, test_df


def process_combined_features(train_df, test_df, feature_name):
    combined_df = pd.concat([train_df, test_df], axis=0)
    combined_df[feature_name] = combined_df[feature_name].apply(lambda x: x.split(', ') if x != 'UNKNOWN' else [])
    
    mlb = MultiLabelBinarizer()
    binary_data = pd.DataFrame(mlb.fit_transform(combined_df[feature_name]), columns=mlb.classes_, index=combined_df.index)
    
    # Splitting the datasets back to train and test
    train_binary_data = binary_data.iloc[:len(train_df)]
    test_binary_data = binary_data.iloc[len(train_df):]
    
    train_df = train_df.drop(feature_name, axis=1)
    test_df = test_df.drop(feature_name, axis=1)

    train_df = pd.concat([train_df, train_binary_data], axis=1)
    test_df = pd.concat([test_df, test_binary_data], axis=1)

    return train_df, test_df

# Data preprocessing pipeline
def data_preprocessing_pipeline(train_df, test_df):
    # Convert duration to minutes
    train_df['Duration'] = train_df['Duration'].apply(convert_to_minutes)
    test_df['Duration'] = test_df['Duration'].apply(convert_to_minutes)
    
    # Process genres and studios on combined datasets
    train_df, test_df = process_combined_features(train_df, test_df, 'Genres')

    # One-hot encode necessary columns
    columns_to_encode = ['Type', 'Source']
    train_df, test_df = process_combined_one_hot_encoding(train_df, test_df, columns_to_encode)
    
    return train_df, test_df

anime_fulldata_train, anime_fulldata_test = data_preprocessing_pipeline(anime_fulldata_train, anime_fulldata_test)

# Drop unnecessary columns for training and testing. Username, Anime Title and Image URL
anime_fulldata_train = anime_fulldata_train.drop(columns=['Username', 'Image URL','Studios'], axis=1)
anime_fulldata_test = anime_fulldata_test.drop(columns=['Username', 'Image URL','Studios'], axis=1)

# Print number of rows and columns
print(colored(f"Number of rows in the train dataset: {anime_fulldata_train.shape[0]}", "green"))
print(colored(f"Number of columns in the train dataset: {anime_fulldata_train.shape[1]}", "green"))

print(colored(f"Number of rows in the test dataset: {anime_fulldata_test.shape[0]}", "green"))
print(colored(f"Number of columns in the test dataset: {anime_fulldata_test.shape[1]}", "green"))

# print first 5 rows of the dataset
display(style_dataframe(anime_fulldata.head(5)))
# Out:
# Number of rows in the train dataset: 49360
# Number of columns in the train dataset: 49
# Number of rows in the test dataset: 877
# Number of columns in the test dataset: 49
#     <style type="text/css">
#     table {
#         color: #333; /* Lighten up font color */
#         font-family: Helvetica, Arial, sans-serif;
#         width: 640px;
#         border-collapse:
#         collapse;
#         border-spacing: 0;
#         margin: 20px auto;
#     }
#
#     td, th {
#         border: 1px solid transparent; /* No more visible border */
#         height: 30px;
#         transition: all 0.3s;  /* Simple transition for hover effect */
#     }
#
#     th {
#         background: #DFDFDF;  /* Darken header a bit */
#         font-weight: bold;
#     }
#
#     td {
#         background: #FAFAFA;
#         text-align: center;
#     }
#
#     /* Cells in even rows (2,4,6...) are one color */
#     tr:nth-child(even) td { background: #F1F1F1; }
#
# ...

# %% [markdown]
# ## Dataset Details
#
# ### `anime_fulldata`:
#
# - **anime_id**: Unique identifier for each anime.
# - **anime_title**: The full name of the anime.
# - **Genres**: Comma-separated list of genres associated with the anime.
# - **Type**: The format of the anime (e.g., movie, TV, OVA, etc.).
# - **Studios**: The studio responsible for producing the anime.
# - **Source**: The origin of the content (e.g., manga, original, light novel, etc.).
# - **Duration**: The length of each episode.
# - **Image URL**: The URL of the anime's cover photo.
# - **user_id**: Non-identifiable, randomly generated user ID.
# - **Username**: The nickname of the user.
# - **user_rating**: The rating out of 10 that the user has assigned to the anime.

# %%
# Set a consistent style for Matplotlib figures
sns.set_style("whitegrid")
plt.rcParams['axes.titlesize'] = 22
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Create a dataframe for rating counts
anime_ratingCount = (anime_fulldata.groupby(by = ['anime_title'])['user_rating']
                     .count()
                     .reset_index()
                     .rename(columns = {'user_rating': 'totalRatingCount'})
                     [['anime_title', 'totalRatingCount']]
                    )

# Visualization 1: Top 10 Anime Based on Rating Counts
top10_animerating = anime_ratingCount[['anime_title', 'totalRatingCount']].sort_values(by='totalRatingCount', ascending=False).head(10)
plt.figure(figsize=(14, 7))
ax = sns.barplot(x="anime_title", y="totalRatingCount", data=top10_animerating, palette="viridis")
ax.set_title('Top 10 Anime Based on Rating Counts')
ax.set_xlabel('Anime Title')
ax.set_ylabel('Total Rating Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.tight_layout()
plt.show()

# Visualization 2: Distribution of User Ratings
plt.figure(figsize=(14, 7))
plt.hist(anime_fulldata['user_rating'], bins=70, color='skyblue', alpha=0.7)
plt.title('Distribution of User Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Visualization 3: Medium of Streaming (Pie Chart)
labels = anime_fulldata['Type'].value_counts().index
values = anime_fulldata['Type'].value_counts().values
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=20, marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.update_layout(title_text='Medium of Streaming', title_x=0.5)
fig.show()

# Visualization 4: Word Cloud for Genres
all_genres = defaultdict(int)
for genres in anime_fulldata['Genres']:
    for genre in genres.split(','):
        all_genres[genre.strip()] += 1

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=400,
    colormap='viridis'
).generate_from_frequencies(all_genres)

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Most Popular Genres in Anime')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌟 Visualization Insights
#
# ---
#
# ### 🏆 1. Top 10 Anime Based on Rating Counts
#
# The bar chart elegantly unveils the crème de la crème of anime, ranked by user ratings' abundance. Standing at the pinnacle are:
#
# - **Bleach**: An epic saga that continues to enchant the masses, crowning it with the zenith of ratings.
# - **Naruto**: A cultural phenomenon transcending borders, its legacy etched in the annals of anime history through sheer viewer admiration.
# - **Death Note**: A testament to quality over quantity, its concise yet potent narrative bewitches a global audience.
#
# ### 📊 2. Distribution of User Ratings
#
# Behold the histogram, a mirror reflecting the heartbeat of viewer sentiment. Like a crescendo, it reveals a linear ascent in user ratings, an ode to the viewers' tendency to bestow generous praise. This pattern is a whisper of a positive bias or a collective inclination to voice joy over discontent.
#
# ### 📺 3. Medium of Streaming
#
# The pie chart, a colorful tapestry of viewer preference, heralds TV's reign supreme in the kingdom of streaming mediums, with movies as its noble consort. This reign signifies serialized TV shows' magnetic allure. In contrast, ONA (Original Net Animation) remains a path less traveled, an undiscovered treasure lingering on the horizon of mainstream recognition.
#
# ### 🎭 4. Most Popular Genres
#
# Amidst the ethereal mist of the word cloud, genres that captivate the soul emerge:
#
# - **Adventure & Action**: A clarion call for thrill-seekers, these genres sail on the winds of viewers' insatiable quest for narratives pulsating with life and vigor.
# - **Fantasy**: A window into the boundless realms of imagination, beckoning viewers to suspend disbelief and partake in awe-inspiring journeys.
# - **Comedy & Drama**: The twin masks of performance, reflecting the human condition's dichotomy—invoking laughter and tears, in a celebration of life's rich tapestry.
# - **Romance & Supernatural**: Subtle yet profound, these genres resonate with the heart's whispers and the shadows that flicker just beyond sight, revealing viewers' yearning for tales that echo life's multifaceted mystery.
#
# ---

# %%
#Implementing necessary functions

def cosine_similarity(vector1, vector2):
    dot_product = np.dot(vector1, vector2)
    norm1 = np.linalg.norm(vector1)
    norm2 = np.linalg.norm(vector2)
    return dot_product / (norm1 * norm2)

def mean_absolute_error(predictions, actual):
    absolute_errors = [abs(x - y) for x, y in zip(predictions, actual)]
    return sum(absolute_errors) / len(absolute_errors)

def k_nearest_neighbors(X_train, X_test, y_train, k, similarity_func):
    predictions = []
    
    for i in range(len(X_test)):
        distances = []

        for j in range(len(X_train)):
            dist = similarity_func(X_test[i], X_train[j])
            # prediction rating, distance
            distances.append((y_train[j], dist))
        
        distances.sort(key=lambda x: x[1], reverse=True)
        neighbors = distances[:k]
        
        predicted_class = np.mean([neighbor[0] for neighbor in neighbors])
        predictions.append(predicted_class)
    
    return predictions


def weighted_k_nearest_neighbors(X_train, X_test, y_train, k, similarity_func):
    predictions = []
    
    for i in range(len(X_test)):
        distances = []

        for j in range(len(X_train)):
            dist = similarity_func(X_test[i], X_train[j])
            distances.append((y_train[j], dist))
        
        distances.sort(key=lambda x: x[1], reverse=True)
        neighbors = distances[:k]
        
        sum_weights = sum([neighbor[1] for neighbor in neighbors])
        predicted_value = sum([neighbor[0] * neighbor[1] for neighbor in neighbors]) / sum_weights if sum_weights > 0 else 0
        predictions.append(predicted_value)
    
    return predictions

# %%
# Prepare data for KNN

# Normalize the features for anime_fulldata_train
features = anime_fulldata_train.drop(['anime_id', 'user_id', 'anime_title', 'user_rating'], axis=1)
scaler = MinMaxScaler()
normalized_features = scaler.fit_transform(features)
normalized_df_train = pd.DataFrame(normalized_features, columns=features.columns)

normalized_df_train['user_id'] = anime_fulldata_train['user_id']
normalized_df_train['user_rating'] = anime_fulldata_train['user_rating']
normalized_df_train['anime_id'] = anime_fulldata_train['anime_id']

X_train = normalized_df_train.drop(['user_rating'], axis=1)  # features
y_train = normalized_df_train['user_rating']  # target variable

# Normalize the features for anime_fulldata_test
features = anime_fulldata_test.drop(['anime_id', 'user_id', 'anime_title', 'user_rating'], axis=1)
scaler = MinMaxScaler()
normalized_features = scaler.fit_transform(features)
normalized_df_test = pd.DataFrame(normalized_features, columns=features.columns)

normalized_df_test['user_id'] = anime_fulldata_test['user_id']
normalized_df_test['user_rating'] = anime_fulldata_test['user_rating']
normalized_df_test['anime_id'] = anime_fulldata_test['anime_id']

X_test = normalized_df_test.drop(['user_rating'], axis=1)  # features
y_test = normalized_df_test['user_rating']  # target variable

# %%
# Initialize k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Initialize a list to store the results as dictionaries
results = []

# Loop over different values of k
for k in [3, 5, 7]:
    knn_mae, weighted_knn_mae = [], []

    # Perform k-fold cross-validation
    for train_idx, test_idx in kf.split(X_train):
        Xtrain, Xval = X_train.iloc[train_idx], X_train.iloc[test_idx]
        ytrain, yval = y_train.iloc[train_idx], y_train.iloc[test_idx]

        # Get predictions from the models
        knn_preds = k_nearest_neighbors(Xtrain.to_numpy(), Xval.to_numpy(), ytrain.to_numpy(), k, cosine_similarity)
        weighted_knn_preds = weighted_k_nearest_neighbors(Xtrain.to_numpy(), Xval.to_numpy(), ytrain.to_numpy(), k, cosine_similarity)

        # Calculate the MAE for this fold
        knn_mae.append(mean_absolute_error(knn_preds, yval))
        weighted_knn_mae.append(mean_absolute_error(weighted_knn_preds, yval))

    # Record the average MAE for this value of k
    results.append({
        'K Value': k,
        'MAE (KNN)': np.mean(knn_mae),
        'MAE (Weighted KNN)': np.mean(weighted_knn_mae)
    })

# Convert the list of dictionaries to a DataFrame
results_df = pd.DataFrame(results)

# Plot the MAE for different k values
plt.figure(figsize=(10, 6))
plt.plot(results_df['K Value'], results_df['MAE (KNN)'], marker='o', linestyle='-', label='KNN')
plt.plot(results_df['K Value'], results_df['MAE (Weighted KNN)'], marker='s', linestyle='--', label='Weighted KNN')
plt.title('K Value vs. Mean Absolute Error')
plt.xlabel('K Value')
plt.ylabel('Mean Absolute Error')
plt.xticks(results_df['K Value'])
plt.legend()
plt.grid(True)
plt.show()

# %%
display(HTML('<h2 style="color: green; text-align: center;">Results:</h2>'))

styled_df = style_dataframe(results_df)
display(styled_df)
# Out:
# <h2 style="color: green; text-align: center;">Results:</h2>
#     <style type="text/css">
#     table {
#         color: #333; /* Lighten up font color */
#         font-family: Helvetica, Arial, sans-serif;
#         width: 640px;
#         border-collapse:
#         collapse;
#         border-spacing: 0;
#         margin: 20px auto;
#     }
#
#     td, th {
#         border: 1px solid transparent; /* No more visible border */
#         height: 30px;
#         transition: all 0.3s;  /* Simple transition for hover effect */
#     }
#
#     th {
#         background: #DFDFDF;  /* Darken header a bit */
#         font-weight: bold;
#     }
#
#     td {
#         background: #FAFAFA;
#         text-align: center;
#     }
#
#     /* Cells in even rows (2,4,6...) are one color */
#     tr:nth-child(even) td { background: #F1F1F1; }
#
#     /* Cells in odd rows (1,3,5...) are another (excludes header cells)  */
#     tr:nth-child(odd) td { background: #FEFEFE; }
#
# ...

# %% [markdown]
# # 📊 **Analysis**
#
# ---
#
# ## 📌 **Key Observations**
#
# ### 1. **Performance for Different k-values**
#
# - **For \(k=3\)**: The MAE (Mean Absolute Error) for both KNN and Weighted KNN is approximately 1.2927. This suggests that, on average, the model's predictions deviate by about 1.2927 units from the actual values. Interestingly, the performance difference between KNN and Weighted KNN is almost imperceptible at this stage.
#
# - **For \(k=5\)**: A slight enhancement is observed as the MAE descends to around 1.2505 for both models. This implies that considering five neighbors, as opposed to three, refines the prediction accuracy.
#
# - **For \(k=7\)**: The MAE achieves its best, dipping to approximately 1.2252. This performance is the most commendable among the three k-values evaluated.
#
# ### 2. **KNN vs. Weighted KNN**
#
# The performance delta between KNN and Weighted KNN remains minuscule across all k-values. This might hint at a relatively uniform distribution of data points in the feature space. Alternatively, the noise in the dataset might be such that the weighting mechanism doesn't offer a pronounced advantage.
#
# ### 3. **Optimal k-value**
#
# From the insights gleaned, \(k=7\) emerges as the optimal choice, boasting the lowest MAE. However, a noteworthy aspect is the diminishing returns in MAE improvement as k escalates. This trend insinuates that ramping up k further might not yield substantial enhancements. In fact, it could backfire, leading to augmented computational overheads and potential underfitting risks.
#
# ---

# %% [markdown]
# # Testing

# %%
# Initialize a list to store the results as dictionaries
results = []

# Loop over different values of k
for k in [3, 5, 7]:

    print(colored(f"KNN Predictions for k = {k}:", "green"))

    knn_mae, weighted_knn_mae = [], []

    # Get predictions from the models
    knn_preds = k_nearest_neighbors(X_train.to_numpy(), X_test.to_numpy(), y_train.to_numpy(), k, cosine_similarity)
    weighted_knn_preds = weighted_k_nearest_neighbors(X_train.to_numpy(), X_test.to_numpy(), y_train.to_numpy(), k, cosine_similarity)

    # Calculate and store MAE
    knn_mae.append(mean_absolute_error(y_test, knn_preds))
    weighted_knn_mae.append(mean_absolute_error(y_test, weighted_knn_preds))

    # Record the average MAE for this value of k
    results.append({
        'K Value': k,
        'MAE (KNN)': np.mean(knn_mae),
        'MAE (Weighted KNN)': np.mean(weighted_knn_mae)
    })

# Convert the list of dictionaries to a DataFrame
results_df = pd.DataFrame(results)

# Plot the MAE for different k values
plt.figure(figsize=(10, 6))
plt.plot(results_df['K Value'], results_df['MAE (KNN)'], marker='o', linestyle='-', label='KNN')
plt.plot(results_df['K Value'], results_df['MAE (Weighted KNN)'], marker='s', linestyle='--', label='Weighted KNN')
plt.title('K Value vs. Mean Absolute Error')
plt.xlabel('K Value')
plt.ylabel('Mean Absolute Error')
plt.xticks(results_df['K Value'])
plt.legend()
plt.grid(True)
plt.show()
# Out:
# KNN Predictions for k = 3:
# KNN Predictions for k = 5:
# KNN Predictions for k = 7:

# %%
display(HTML('<h2 style="color: green; text-align: center;">Results for test:</h2>'))

styled_df = style_dataframe(results_df)
display(styled_df)
# Out:
# <h2 style="color: green; text-align: center;">Results for test:</h2>
#     <style type="text/css">
#     table {
#         color: #333; /* Lighten up font color */
#         font-family: Helvetica, Arial, sans-serif;
#         width: 640px;
#         border-collapse:
#         collapse;
#         border-spacing: 0;
#         margin: 20px auto;
#     }
#
#     td, th {
#         border: 1px solid transparent; /* No more visible border */
#         height: 30px;
#         transition: all 0.3s;  /* Simple transition for hover effect */
#     }
#
#     th {
#         background: #DFDFDF;  /* Darken header a bit */
#         font-weight: bold;
#     }
#
#     td {
#         background: #FAFAFA;
#         text-align: center;
#     }
#
#     /* Cells in even rows (2,4,6...) are one color */
#     tr:nth-child(even) td { background: #F1F1F1; }
#
#     /* Cells in odd rows (1,3,5...) are another (excludes header cells)  */
#     tr:nth-child(odd) td { background: #FEFEFE; }
#
# ...

# %% [markdown]
# # 📊 **Analysis of KNN vs. Weighted KNN Performance**
#
# ---
#
# ## 📌 **Key Observations**
#
# ### 1. **Performance for Different k-values**
#
# - **For \(k=3\)**: Both KNN and Weighted KNN have an MAE (Mean Absolute Error) of approximately 1.3124. This indicates that, on average, the predictions from both models deviate by about 1.3124 units from the actual values. The identical performance suggests that the weighting mechanism doesn't provide any advantage for this k-value.
#
# - **For \(k=5\)**: There's an improvement in the MAE, which drops to around 1.2627 for both models. This suggests that considering five neighbors, as opposed to three, offers a more accurate prediction.
#
# - **For \(k=7\)**: The MAE further improves, decreasing to approximately 1.2380. This is the best performance among the three k-values evaluated.
#
# ### 2. **KNN vs. Weighted KNN**
#
# Across all k-values, the performance of KNN and Weighted KNN is identical. This might indicate that the data points are relatively uniformly distributed in the feature space, or that the inherent noise in the data makes the weighting mechanism redundant.
#
# ### 3. **Optimal k-value**
#
# From the data provided, \(k=7\) emerges as the optimal choice, having the lowest MAE. However, it's important to note that the improvement in MAE as we increase k is diminishing. This suggests that further increasing k might not lead to significant improvements and might even lead to worse performance due to increased computational costs and potential underfitting.
#
# ---

# %% [markdown]
# # Assignment 1: Part 3
#
# ### Anime Recommendation

# %%
def k_nearest_neighbors_anime_recommendation(data, query_index, k, similarity_func):
    distances = []

    for j in range(len(data)):
        if j == query_index:
            continue  # Skip the query index
        dist = similarity_func(data[query_index], data[j])
        distances.append((j, dist))

    # Exclude the query index
    distances = [(j, dist) for j, dist in distances if j != query_index]

    # Sort by similarity
    distances.sort(key=lambda x: x[1], reverse=True)

    # Get the top k most similar indices
    neighbors = distances[:k]


    return neighbors  # Returns a list of tuples (index, similarity)

# %%
# Combine train and test data for anime recommendation
anime_fulldata = pd.concat([anime_fulldata_train, anime_fulldata_test], axis=0, ignore_index=True)

# Group the data by 'anime_title' and calculate the mean 'user_rating' for each anime.
anime_ratings = anime_fulldata.groupby('anime_title')['user_rating'].mean().reset_index()

# Drop duplicate rows based on 'anime_title', keeping only the first occurrence.
anime_features = anime_fulldata.drop_duplicates(subset='anime_title', keep='first')

# Merge the 'anime_features' DataFrame with the 'anime_ratings' DataFrame on the 'anime_title' column.
anime_features = pd.merge(anime_features, anime_ratings, on='anime_title', how='left', suffixes=('', '_mean'))

# Rename the 'user_rating_mean' column to 'mean_user_rating' for clarity.
anime_features.rename(columns={'user_rating_mean': 'mean_user_rating'}, inplace=True)

# Drop unnecessary columns 'anime_id', 'user_id', and 'user_rating' as they are not needed for recommendations.
anime_features.drop(['anime_id', 'user_id', 'user_rating'], axis=1, inplace=True)

# %%
anime_feature= anime_features.copy()

# Anime Index for which you want to get recommendations
target_index = 0

# Get the title of the anime for which you're making recommendations
target_anime_title = anime_feature.iloc[target_index]['anime_title']

# Keep a copy of anime titles
anime_titles = anime_feature['anime_title'].copy()

# Predicting the top 10 animes similar to the target anime
preds = k_nearest_neighbors_anime_recommendation(anime_feature.drop(['anime_title'], axis=1).to_numpy(), target_index, 10, cosine_similarity)

# Extract the indices of the recommended animes from the preds
indices = [index for index, _ in preds]

# Get unique titles from the indices, preserving the order
titles_seen = set()
unique_titles = []
for i in indices:
    title = anime_titles.iloc[i]
    if title not in titles_seen:
        unique_titles.append(title)
        titles_seen.add(title)

# %%
# Create the HTML content for styling
html_content = f'''
<div style="font-family: Arial, sans-serif;">
    <h2 style="color: #4CAF50; text-align: center;">🌟 Recommendations for "{target_anime_title}" 🌟</h2>
    <ul style="background-color: #f2f2f2; border: 1px solid #e0e0e0; border-radius: 5px; padding: 20px;">
'''

for i, title in enumerate(titles_seen, 1):
    html_content += f'''
    <li style="margin-bottom: 10px; font-size: 18px;">
        <span style="color: #555555;"><strong>{i}.</strong> {title}</span>
    </li>
    '''

html_content += '''
    </ul>
</div>
'''

# Display the HTML content
display(HTML(html_content))
# Out:
# <div style="font-family: Arial, sans-serif;">
#     <h2 style="color: #4CAF50; text-align: center;">🌟 Recommendations for "Cowboy Bebop" 🌟</h2>
#     <ul style="background-color: #f2f2f2; border: 1px solid #e0e0e0; border-radius: 5px; padding: 20px;">
#
#     <li style="margin-bottom: 10px; font-size: 18px;">
#         <span style="color: #555555;"><strong>1.</strong> Solty Rei</span>
#     </li>
#
#     <li style="margin-bottom: 10px; font-size: 18px;">
#         <span style="color: #555555;"><strong>2.</strong> Kuromukuro</span>
#     </li>
#
#     <li style="margin-bottom: 10px; font-size: 18px;">
#         <span style="color: #555555;"><strong>3.</strong> Tengen Toppa Gurren Lagann</span>
#     </li>
#
#     <li style="margin-bottom: 10px; font-size: 18px;">
#         <span style="color: #555555;"><strong>4.</strong> Buddy Complex</span>
#     </li>
#
#     <li style="margin-bottom: 10px; font-size: 18px;">
# ...
